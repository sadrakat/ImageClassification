# %% [markdown]
# Homework Assignment 4

# %% [markdown]
# a.Take at least 100 images per class with at least 3 classes using your phone/camera (you can take advantage of spring in Bloomington and take photos of different trees, flowers, animals).Display 5 examples from each class.

# %%
import os
import random
import matplotlib.pyplot as plt

# Define the directories and classes
base_dir = "C:/Users/srnav/Desktop/Indiana University/Second Sem/AML"
class_names = ["Trees1", "Flowers1", "Animals1"]

# Display 5 random images from each class
for class_name in class_names:
    class_dir = os.path.join(base_dir, class_name)
    image_names = os.listdir(class_dir)
    random.shuffle(image_names)
    plt.figure(figsize=(10,5))
    for i in range(5):
        img_path = os.path.join(class_dir, image_names[i])
        img = plt.imread(img_path)
        plt.subplot(1, 5, i+1)
        plt.imshow(img)
        plt.axis("off")
    plt.show()

# %% [markdown]
# b. Split the images into a training set, a validation set, and a test set.

# %%
import os
import shutil

# Define the directories and classes
base_dir = "C:/Users/srnav/Desktop/Indiana University/Second Sem/AML"
train_dir = os.path.join(base_dir, "train")
val_dir = os.path.join(base_dir, "val")
test_dir = os.path.join(base_dir, "test")
class_names = ["Trees1", "Flowers1", "Animals1"]

# Create the directories
for dir in [train_dir, val_dir, test_dir]:
    for class_name in class_names:
        os.makedirs(os.path.join(dir, class_name))

# Split the images into the train, val, and test sets
for class_name in class_names:
    class_dir = os.path.join(base_dir, class_name)
    image_names = os.listdir(class_dir)
    random.shuffle(image_names)
    train_size = int(0.6 * len(image_names))
    val_size = int(0.2 * len(image_names))
    train_names = image_names[:train_size]
    val_names = image_names[train_size:train_size+val_size]
    test_names = image_names[train_size+val_size:]
    for name in train_names:
        src_path = os.path.join(class_dir, name)
        dst_path = os.path.join(train_dir, class_name, name)
        shutil.copy(src_path, dst_path)
    for name in val_names:
        src_path = os.path.join(class_dir, name)
        dst_path = os.path.join(val_dir, class_name, name)
        shutil.copy(src_path, dst_path)
    for name in test_names:
        src_path = os.path.join(class_dir, name)
        dst_path = os.path.join(test_dir, class_name, name)
        shutil.copy(src_path, dst_path)

# %% [markdown]
# c. Build the input pipeline, including the appropriate preprocessing operations, and add data
# augmentation.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define data generators with data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,           # rescale pixel values to [0, 1] range
    rotation_range=20,        # randomly rotate images by up to 20 degrees
    width_shift_range=0.1,    # randomly shift images horizontally by up to 10%
    height_shift_range=0.1,   # randomly shift images vertically by up to 10%
    shear_range=0.2,          # randomly apply shearing transformations
    zoom_range=0.2,           # randomly zoom in or out on images
    horizontal_flip=True,     # randomly flip images horizontally
    fill_mode='nearest'       # fill in missing pixels with the nearest available
)

val_datagen = ImageDataGenerator(
    rescale=1./255            # rescale pixel values to [0, 1] range
)

test_datagen = ImageDataGenerator(
    rescale=1./255            # rescale pixel values to [0, 1] range
)

# Set the batch size
batch_size = 32

# Define the train, validation, and test data generators
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 194 images belonging to 3 classes.
# Found 64 images belonging to 3 classes.
# Found 68 images belonging to 3 classes.

# %% [markdown]
# d. Fine-tune a pretrained model of your choice on this dataset (the one you created in part c).
# Report classification accuracy and give a few examples of correct/incorrect classification (show a
# few images that were correctly/incorrectly classified).

# %%
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the input size of your images
IMG_SIZE = 224

# Define the number of classes in your dataset
NUM_CLASSES = 3

# Define the batch size for training and evaluation
BATCH_SIZE = 32

# Define the path to your dataset
DATA_DIR = "C:/Users/srnav/Desktop/Indiana University/Second Sem/AML"


# Load the pre-trained ResNet50 model and replace the top layers for fine-tuning
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))

x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(1024, activation='relu')(x)
predictions = tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')(x)

model = tf.keras.models.Model(inputs=base_model.input, outputs=predictions)

# Freeze the base layers of the model
for layer in base_model.layers:
    layer.trainable = False

# Compile the model with an optimizer, loss function, and evaluation metric
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model on the training data with the validation data for early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5, verbose=1)
history = model.fit(train_generator, epochs=50, validation_data=val_generator, callbacks=[early_stopping])

# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(test_generator)

print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)

# Predict the classes of the test data and plot some examples of correct and incorrect predictions
import numpy as np
import matplotlib.pyplot as plt

preds = model.predict(test_generator)
predicted_classes = np.argmax(preds, axis=1)

true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

correct_indices = np.nonzero(predicted_classes == true_classes)[0]
incorrect_indices = np.nonzero(predicted_classes != true_classes)[0]

print('Number of correct predictions:', len(correct_indices))
print('Number of incorrect predictions:', len(incorrect_indices))
# Out:
# Epoch 1/50
# 7/7 [==============================] - 9s 922ms/step - loss: 1.8930 - accuracy: 0.3093 - val_loss: 2.2826 - val_accuracy: 0.3906
# Epoch 2/50
# 7/7 [==============================] - 6s 799ms/step - loss: 1.8779 - accuracy: 0.3351 - val_loss: 1.2274 - val_accuracy: 0.2969
# Epoch 3/50
# 7/7 [==============================] - 6s 932ms/step - loss: 1.2580 - accuracy: 0.3660 - val_loss: 1.2207 - val_accuracy: 0.3906
# Epoch 4/50
# 7/7 [==============================] - 6s 844ms/step - loss: 1.1726 - accuracy: 0.4278 - val_loss: 1.0667 - val_accuracy: 0.5000
# Epoch 5/50
# 7/7 [==============================] - 6s 885ms/step - loss: 1.0512 - accuracy: 0.5464 - val_loss: 0.9845 - val_accuracy: 0.5938
# Epoch 6/50
# 7/7 [==============================] - 6s 886ms/step - loss: 1.0378 - accuracy: 0.4639 - val_loss: 0.9838 - val_accuracy: 0.5938
# Epoch 7/50
# 7/7 [==============================] - 6s 866ms/step - loss: 1.1261 - accuracy: 0.4278 - val_loss: 0.9595 - val_accuracy: 0.5156
# Epoch 8/50
# 7/7 [==============================] - 6s 852ms/step - loss: 1.1028 - accuracy: 0.4124 - val_loss: 0.9649 - val_accuracy: 0.4688
# Epoch 9/50
# 7/7 [==============================] - 6s 858ms/step - loss: 1.1633 - accuracy: 0.4227 - val_loss: 0.9528 - val_accuracy: 0.5781
# Epoch 10/50
# 7/7 [==============================] - 6s 850ms/step - loss: 1.0842 - accuracy: 0.4381 - val_loss: 0.9994 - val_accuracy: 0.4219
# Epoch 10: early stopping
# 3/3 [==============================] - 1s 383ms/step - loss: 1.0289 - accuracy: 0.4559
# Test loss: 1.028882384300232
# Test accuracy: 0.45588234066963196
# 3/3 [==============================] - 2s 384ms/step
# Number of correct predictions: 23
# Number of incorrect predictions: 45

# %%
import matplotlib.pyplot as plt
import numpy as np

# plot some correctly classified images
fig, axs = plt.subplots(1, 5, figsize=(15, 15))
axs = axs.flatten()
for i in range(5):
    idx = correct_indices[i]
    img_path = test_generator.filepaths[idx]
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=(img_height, img_width))
    img = np.array(img)
    axs[i].imshow(img)
    axs[i].axis('off')
    true_class = class_names[true_classes[idx]]
    axs[i].set_title('True: {}'.format(true_class))
    

    
# plot some incorrectly classified images
fig, axs = plt.subplots(1, 5, figsize=(15, 15))
axs = axs.flatten()
for i in range(5):
    idx = incorrect_indices[i]
    img_path = test_generator.filepaths[idx]
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=(img_height, img_width))
    img = np.array(img)
    axs[i].imshow(img)
    axs[i].axis('off')
    true_class = class_names[predicted_classes[idx]]
    axs[i].set_title('False: {}'.format(true_class))

# %% [markdown]
# e.Train from scratch (without pretraining) a deep neural network that containsconvolutional layers on this dataset (the one you created in part c). Report classification accuracyand give a few examples of correct/incorrect classification (show a few images that were correctly/incorrectly classified). Note: The objective of this question is to illustrate that training deep networks from scratch requires a lot of data so it is ok if your classification accuracy is low.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Set up data augmentation and preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

# Load and prepare training and test datasets
train_generator = train_datagen.flow_from_directory(
    'C:/Users/srnav/Desktop/Indiana University/Second Sem/AML/train',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    'C:/Users/srnav/Desktop/Indiana University/Second Sem/AML/val',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical')

# Define the model architecture
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(224, 224, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=50,
    validation_data=validation_generator,
    validation_steps=len(validation_generator))

# Evaluate the model on the test set
test_generator = test_datagen.flow_from_directory(
    'C:/Users/srnav/Desktop/Indiana University/Second Sem/AML/test',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical')

test_loss, test_acc = model.evaluate(test_generator, steps=len(test_generator))
print('Test accuracy:', test_acc)
# Out:
# Found 194 images belonging to 3 classes.
# Found 64 images belonging to 3 classes.
# Epoch 1/50
# 7/7 [==============================] - 4s 566ms/step - loss: 5.7315 - accuracy: 0.3660 - val_loss: 1.0917 - val_accuracy: 0.3750
# Epoch 2/50
# 7/7 [==============================] - 3s 463ms/step - loss: 1.1032 - accuracy: 0.3711 - val_loss: 1.0613 - val_accuracy: 0.3750
# Epoch 3/50
# 7/7 [==============================] - 3s 538ms/step - loss: 1.0479 - accuracy: 0.5258 - val_loss: 1.0118 - val_accuracy: 0.4531
# Epoch 4/50
# 7/7 [==============================] - 3s 467ms/step - loss: 1.0473 - accuracy: 0.4485 - val_loss: 1.0698 - val_accuracy: 0.3750
# Epoch 5/50
# 7/7 [==============================] - 3s 535ms/step - loss: 1.0054 - accuracy: 0.5000 - val_loss: 0.9077 - val_accuracy: 0.6875
# Epoch 6/50
# 7/7 [==============================] - 3s 474ms/step - loss: 0.8938 - accuracy: 0.5979 - val_loss: 0.9276 - val_accuracy: 0.5625
# Epoch 7/50
# 7/7 [==============================] - 3s 475ms/step - loss: 0.7956 - accuracy: 0.6856 - val_loss: 1.2272 - val_accuracy: 0.4062
# Epoch 8/50
# 7/7 [==============================] - 3s 471ms/step - loss: 1.0466 - accuracy: 0.5155 - val_loss: 1.0568 - val_accuracy: 0.4688
# Epoch 9/50
# 7/7 [==============================] - 4s 492ms/step - loss: 0.8507 - accuracy: 0.6753 - val_loss: 0.8494 - val_accuracy: 0.5781
# Epoch 10/50
# 7/7 [==============================] - 4s 485ms/step - loss: 0.6569 - accuracy: 0.7474 - val_loss: 0.8618 - val_accuracy: 0.6094
# Epoch 11/50
# 7/7 [==============================] - 4s 516ms/step - loss: 0.5140 - accuracy: 0.7887 - val_loss: 0.6809 - val_accuracy: 0.7031
# Epoch 12/50
# 7/7 [==============================] - 4s 531ms/step - loss: 0.5255 - accuracy: 0.8041 - val_loss: 0.8243 - val_accuracy: 0.6719
# Epoch 13/50
# 7/7 [==============================] - 4s 535ms/step - loss: 0.4120 - accuracy: 0.8763 - val_loss: 0.6411 - val_accuracy: 0.7188
# Epoch 14/50
# 7/7 [==============================] - 4s 548ms/step - loss: 0.4136 - accuracy: 0.8866 - val_loss: 1.6174 - val_accuracy: 0.5312
# Epoch 15/50
# 7/7 [==============================] - 4s 560ms/step - loss: 0.7016 - accuracy: 0.7113 - val_loss: 0.7853 - val_accuracy: 0.6875
# Epoch 16/50
# 7/7 [==============================] - 4s 570ms/step - loss: 0.5996 - accuracy: 0.7113 - val_loss: 0.9020 - val_accuracy: 0.5781
# Epoch 17/50
# 7/7 [==============================] - 4s 656ms/step - loss: 0.5406 - accuracy: 0.7629 - val_loss: 0.6860 - val_accuracy: 0.7344
# Epoch 18/50
# 7/7 [==============================] - 4s 539ms/step - loss: 0.4087 - accuracy: 0.7990 - val_loss: 0.9518 - val_accuracy: 0.6406
# Epoch 19/50
# 7/7 [==============================] - 4s 512ms/step - loss: 0.3499 - accuracy: 0.8557 - val_loss: 0.8344 - val_accuracy: 0.7344
# Epoch 20/50
# 7/7 [==============================] - 4s 589ms/step - loss: 0.2675 - accuracy: 0.8814 - val_loss: 1.2656 - val_accuracy: 0.6250
# Epoch 21/50
# 7/7 [==============================] - 4s 506ms/step - loss: 0.3102 - accuracy: 0.8660 - val_loss: 0.7623 - val_accuracy: 0.7500
# Epoch 22/50
# 7/7 [==============================] - 4s 488ms/step - loss: 0.2919 - accuracy: 0.9021 - val_loss: 0.8934 - val_accuracy: 0.6875
# Epoch 23/50
# 7/7 [==============================] - 4s 563ms/step - loss: 0.2424 - accuracy: 0.9227 - val_loss: 0.8031 - val_accuracy: 0.7344
# Epoch 24/50
# 7/7 [==============================] - 3s 561ms/step - loss: 0.2054 - accuracy: 0.9433 - val_loss: 0.8344 - val_accuracy: 0.7188
# Epoch 25/50
# 7/7 [==============================] - 4s 485ms/step - loss: 0.2491 - accuracy: 0.8866 - val_loss: 0.8830 - val_accuracy: 0.7500
# Epoch 26/50
# 7/7 [==============================] - 3s 473ms/step - loss: 0.1485 - accuracy: 0.9536 - val_loss: 0.9059 - val_accuracy: 0.7656
# Epoch 27/50
# 7/7 [==============================] - 4s 499ms/step - loss: 0.1731 - accuracy: 0.9278 - val_loss: 1.0234 - val_accuracy: 0.7344
# Epoch 28/50
# 7/7 [==============================] - 4s 565ms/step - loss: 0.4606 - accuracy: 0.8299 - val_loss: 1.9927 - val_accuracy: 0.6250
# Epoch 29/50
# 7/7 [==============================] - 4s 486ms/step - loss: 0.4913 - accuracy: 0.7887 - val_loss: 0.9142 - val_accuracy: 0.7500
# Epoch 30/50
# 7/7 [==============================] - 3s 555ms/step - loss: 0.3491 - accuracy: 0.8608 - val_loss: 0.9185 - val_accuracy: 0.7344
# Epoch 31/50
# 7/7 [==============================] - 3s 547ms/step - loss: 0.2425 - accuracy: 0.8814 - val_loss: 1.3028 - val_accuracy: 0.7031
# Epoch 32/50
# 7/7 [==============================] - 4s 565ms/step - loss: 0.3130 - accuracy: 0.8608 - val_loss: 1.0000 - val_accuracy: 0.7656
# Epoch 33/50
# 7/7 [==============================] - 4s 508ms/step - loss: 0.2162 - accuracy: 0.9278 - val_loss: 1.6956 - val_accuracy: 0.7031
# Epoch 34/50
# 7/7 [==============================] - 4s 498ms/step - loss: 0.2351 - accuracy: 0.8918 - val_loss: 1.0086 - val_accuracy: 0.8125
# Epoch 35/50
# 7/7 [==============================] - 4s 499ms/step - loss: 0.2745 - accuracy: 0.9381 - val_loss: 1.4970 - val_accuracy: 0.6719
# Epoch 36/50
# 7/7 [==============================] - 4s 495ms/step - loss: 0.2185 - accuracy: 0.9124 - val_loss: 1.1037 - val_accuracy: 0.7344
# Epoch 37/50
# 7/7 [==============================] - 4s 504ms/step - loss: 0.1649 - accuracy: 0.9639 - val_loss: 1.1285 - val_accuracy: 0.7344
# Epoch 38/50
# 7/7 [==============================] - 4s 501ms/step - loss: 0.1951 - accuracy: 0.9588 - val_loss: 0.7161 - val_accuracy: 0.8125
# Epoch 39/50
# 7/7 [==============================] - 4s 501ms/step - loss: 0.1029 - accuracy: 0.9691 - val_loss: 0.8384 - val_accuracy: 0.8281
# Epoch 40/50
# 7/7 [==============================] - 4s 502ms/step - loss: 0.1284 - accuracy: 0.9588 - val_loss: 1.0319 - val_accuracy: 0.7969
# Epoch 41/50
# 7/7 [==============================] - 4s 573ms/step - loss: 0.0830 - accuracy: 0.9742 - val_loss: 1.1880 - val_accuracy: 0.8281
# Epoch 42/50
# 7/7 [==============================] - 4s 500ms/step - loss: 0.0561 - accuracy: 0.9794 - val_loss: 0.9827 - val_accuracy: 0.8438
# Epoch 43/50
# 7/7 [==============================] - 4s 574ms/step - loss: 0.0309 - accuracy: 1.0000 - val_loss: 1.0191 - val_accuracy: 0.8438
# Epoch 44/50
# 7/7 [==============================] - 4s 577ms/step - loss: 0.0247 - accuracy: 1.0000 - val_loss: 1.0729 - val_accuracy: 0.8281
# Epoch 45/50
# 7/7 [==============================] - 4s 500ms/step - loss: 0.0264 - accuracy: 0.9948 - val_loss: 0.8646 - val_accuracy: 0.8438
# Epoch 46/50
# 7/7 [==============================] - 4s 503ms/step - loss: 0.0283 - accuracy: 0.9948 - val_loss: 0.7608 - val_accuracy: 0.8281
# Epoch 47/50
# 7/7 [==============================] - 4s 509ms/step - loss: 0.0430 - accuracy: 0.9794 - val_loss: 1.2835 - val_accuracy: 0.8281
# Epoch 48/50
# 7/7 [==============================] - 4s 507ms/step - loss: 0.0241 - accuracy: 0.9948 - val_loss: 1.1456 - val_accuracy: 0.8438
# Epoch 49/50
# 7/7 [==============================] - 4s 506ms/step - loss: 0.0803 - accuracy: 0.9897 - val_loss: 1.5406 - val_accuracy: 0.7656
# Epoch 50/50
# 7/7 [==============================] - 4s 492ms/step - loss: 0.1958 - accuracy: 0.9433 - val_loss: 0.8791 - val_accuracy: 0.8125
# Found 68 images belonging to 3 classes.
# 3/3 [==============================] - 0s 59ms/step - loss: 1.6545 - accuracy: 0.7794
# Test accuracy: 0.779411792755127

# %%
batch_size = 32
img_height = 224
img_width = 224
num_classes = 3
import numpy as np
import matplotlib.pyplot as plt

preds = model.predict(test_generator)
predicted_classes = np.argmax(preds, axis=1)

true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())



correct_indices = np.where(predicted_classes == true_classes)[0]
incorrect_indices = np.where(predicted_classes != true_classes)[0]

# plot some correctly classified images
fig, axs = plt.subplots(1, 5, figsize=(15, 15))
axs = axs.flatten()
for i in range(5):
    idx = correct_indices[i]
    img_path = test_generator.filepaths[idx]
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=(img_height, img_width))
    img = np.array(img)
    axs[i].imshow(img)
    axs[i].axis('off')
    true_class = class_names[true_classes[idx]]
    axs[i].set_title('True: {}'.format(true_class))

# plot some incorrectly classified images
fig, axs = plt.subplots(1, 5, figsize=(15, 15))
axs = axs.flatten()
for i in range(5):
    idx = incorrect_indices[i]
    img_path = test_generator.filepaths[idx]
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=(img_height, img_width))
    img = np.array(img)
    axs[i].imshow(img)
    axs[i].axis('off')
    true_class = class_names[predicted_classes[idx]]
    axs[i].set_title('False: {}'.format(true_class))
# Out:
# 3/3 [==============================] - 0s 84ms/step
